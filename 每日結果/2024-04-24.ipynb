# %%
def set_color_group(val): # 族群平均漲幅
    if float(val) > 5:
        color = "lightcoral"
    elif 2.5 <= float(val) <= 5:
        color = 'pink'
    elif -5 <= float(val) < -2:
        color = 'lightgreen'
    elif float(val) < -5:
        color = 'green'
    else:
        color = 'white'
    return f'background-color: {color}'

def set_color_rank(val): # 
    if val <= 20:
        color = 'yellow'
    else:
        color = 'white'
    return f'background-color: {color}'

def set_color_per(val):
    if float(val) >= 4:
        color = 'pink'
    elif float(val) <= -4:
        color = "lightgreen"
    else:
        color = 'white'
    return f'background-color: {color}'

def process_cell(cell):
    match = re.match(r'([\d.]+)(億|萬)?', cell)
    if match:
        num = float(match.group(1)) 
        unit = match.group(2)  
        if unit == '萬':
            return round(num*0.0001, 2)
        elif unit == '億':
            return round(num, 2)
    else:
        return cell

# %%
categories = {
    # "權值": ["台積電", "鴻海", "聯發科", "廣達", "台達電", "日月光投控", "聯電", "富邦金", "國泰金", "中華電", "台泥"],
    # "IGNORE": ["中華電", "台泥"],
    "重電": ["華城", "中興電", "士電", "亞力", "大同", "東元", "洋華"],
    "電纜": ["大亞", "華榮", "宏泰", "華電", "華興", "合機", "華新", "億泰", "榮星"],
    "綠能": ["世紀鋼", "森崴能源", "上緯投控", "樂事綠能"],
    "儲能": ["台達電", "光寶科", "康舒", "碩天", "盛達"],
    "太陽能模組": ["元晶", "聯合再生", "茂迪"],
    "水資源": ["國統", "山林水", "中工", "力麒", "欣陸", "中鼎", "中宇"],
    "先進製程": ["台積電"],
    "成熟製程": ["聯電", "世界", "力積電"],
    "半導體設備": ["萬潤", "弘塑", "志聖", "家登", "辛耘", "中砂", "帆宣", "公準", "蔚華科", "大量", "均豪", "均華", "大量", "光洋科"],
    "半導體廠務": ["亞翔", "信紘科", "聖暉*", "漢唐", "洋基工程", "崇越", "牧德"],
    "半導體檢測": ["閎康", "汎銓", "宜特"],
    "半導體化材": ["上品", "達興材料", "勝一", "三福化", "晶呈科技"],
    "半導體矽晶圓": ["環球晶", "台勝科", "中美晶", "合晶"],
    "半導體測試介面": ["旺矽", "穎崴", "精測"],
    "半導體封裝": ["日月光投控", "京元電子"],
    "記憶體": ["群聯", "威剛", "十銓", "宇瞻", "南亞科", "華邦電", "晶豪科", "創見", "至上", "旺宏", "南茂", "力成"],
    "手機IC": ["聯發科", "達發", "瑞昱"],
    "DDIC": ["聯詠", "瑞鼎", "矽創", "天鈺", "敦泰"],
    "PMIC": ["矽力*-KY", "茂達", "力智", "致新"],
    "傳輸IC": ["譜瑞-KY", "祥碩", "信驊"],
    "顯卡": ["撼訊", "麗臺"],
    "連接器": ["嘉澤", "宏致", "良維", "信音"],
    "AI伺服器": ["廣達", "緯創", "緯穎", "技嘉", "英業達", "鴻海"],
    "IP": ["世芯-KY", "創意", "智原", "力旺", "M31",  "愛普*"],
    "中國IC / IP": ["威盛", "金麗科", "晶心科"],
    "神盾集團": ["神盾", "安國", "安格", "驊訊", "芯鼎", "迅杰"],
    "伺服器滑軌": ["川湖", "南俊國際"],
    "散熱": ["奇鋐", "雙鴻", "高力", "建準", "健策", "尼德科超眾", "AMAX-KY", "廣運", "尼得科超眾"],
    "機殼": ["迎廣", "勤誠", "振發", "旭品", "營邦", "晟銘電"],
    "光通訊": ["聯亞", "統新", "光環", "華星光", "訊芯-KY", "聯均", "上詮", "台通", "光聖", "前鼎", "眾達-KY", "波若威", "創威"],
    "軸承": ["兆利", "富世達", "新日興", "信錦"],
    "光學": ["大立光", "玉晶光", "揚明光", "先進光", "亞光", "采鈺"],
    "軍工": ["漢翔", "亞航", "寶一", "雷虎", "邑錡", "中光電", "千附精密", "八貫", "精剛", "龍德造船", "台船", "長榮航太", "全訊"],
    "工業電腦": ["研華", "樺漢", "威強電", "研揚"],
    "機器人": ["所羅門", "廣明", "百達-KY"],
    "生技": ["順藥", "保瑞", "台耀", "美時", "安克", "永昕"],
    "PC": ["宏碁", "華碩", "微星", "仁寶", "義隆", "藍天"],
    "電子紙": ["元太", "振曜"],
    "PA": ["立積", "穩懋", "宏捷科", "全新", "耕興"],
    "GaN": ["漢磊", "嘉晶"],
    "ABF": ["欣興", "南電", "景碩"],
    "CCL / AI PCB": ["台光電", "台燿", "聯茂", "金居", "金像電"],
    "車用PCB": ["定穎投控", "健鼎", "敬鵬"],
    "衛星": ["華通", "燿華", "新復興", "昇達科"],
    "車用電子": ["華孚", "胡連", "乙盛-KY", "新唐", "同欣電"],
    "車用AM": ["東陽", "堤維西", "耿鼎", "帝寶"],
    "營建": ["上曜", "工信","興富發", "潤隆", "日勝生", "華固", "冠德", "長虹", "國產", "國建", "皇昌", "南港", "聯上", "皇普", "永信建", "華建", "三發地產", "櫻花建", "新美齊", "新潤", "愛山林", "亞昕", "坤悅", "晶悅", "昇陽", "富宇", "華友聯", "隆大", "富華新", "皇鼎"],
    "自行車": ["巨大", "美利達"],
    "被動元件": ["國巨", "華新科"],
    "網通": ["啟碁", "中磊", "智易", "智邦", "正文", "海華", "正基", "神準", "合勤控"],
    "成衣製鞋": ["聚陽", "儒鴻", "寶成", "豐泰", "鈺齊-KY"],
    "航運": ["華航", "長榮航"],
    "海運": ["長榮", "陽明", "萬海"],
    "散裝航": ["慧洋-KY", "裕民", "新興"],
    "面板": ["友達", "群創"],
    "金融": ["國泰金", "玉山金", "富邦金", "中信金", "新光金", "台新金", "元大金", "兆豐金"],
    "資安軟體": ["精誠", "敦陽科", "零壹", "宏碁資訊", "邁達特", "緯軟", "凌群"],
    "鋼鐵": ["中鴻", "大成鋼", "長榮鋼"],
    "遊戲": ["鈊象", "智冠", "大宇資", "華義"],
    "紡織": ["南紡"],
    "旅遊": ["雄獅", "山富"]
}

# %%
import pandas as pd
import re
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv(r"C:\Users\User\Downloads\Book1.csv")
基本_籌碼資料 = pd.read_csv(r"C:\Users\User\5. 看盤\投信月營收\2024-04-23 投信月營收.csv"); 基本_籌碼資料.drop(columns=["Unnamed: 0"], inplace=True)
df = pd.merge(df, 基本_籌碼資料, on='代碼', how='left')

df["排名"] = df.index + 1
new_column_order = ['排名'] + [col for col in df.columns if col != '排名']
df = df[new_column_order]

df['族群'] = ''
for index, row in df.iterrows():
    categorized = False
    for category, items in categories.items():
        if row['商品'] in items:
            df.at[index, '族群'] = category
            categorized = True 
            break
    if not categorized:
        df.at[index, '族群'] = "其他"

df["成交值"] = df["成交值"].apply(process_cell)
# df["成交值(億)"] = df["成交值"].str.replace("億", "").astype(float); df.drop(columns=["成交值"], inplace=True)
df["成交值(億)"] = df["成交值"]
df.drop(columns=["成交值"], inplace=True)
df["資金流向(億)"] = round((0.01*(2*df["內外盤比圖"]) - 1) * df["成交值(億)"], 2)
df["內外盤比"] = df["內外盤比圖"]; df.drop(columns=["內外盤比圖"], inplace=True)

df = df[["排名", "商品", "族群", "成交", "60日高點", "總量", "估計量", "10日均量", "月營收YoY", "投信連買天數", "資金流向(億)", "內外盤比", "漲幅%", ]]

# 族群
grouped = df[df['族群'] != '其他']
grouped = grouped.groupby('族群').agg({'商品': 'count', '漲幅%': 'mean'})
grouped.columns = ['檔數', '平均漲幅%']

max_increase_idx = df.groupby('族群')['漲幅%'].idxmax()
max_increase_rows = df.loc[max_increase_idx, ['族群', '商品', '漲幅%']]
max_increase_rows.set_index('族群', inplace=True)
grouped['領漲'] = max_increase_rows['商品']
grouped['領漲漲幅%'] = max_increase_rows['漲幅%']

total_list = []; flow_list = []
for i in range(len(grouped)):
    group_name = grouped.index[i]
    name_list = []
    flow = 0
    for j in range(len(categories[group_name])):
        if categories[group_name][j] in list(df["商品"]):
            name_list.append(categories[group_name][j])
            flow = float(df[df["商品"] == categories[group_name][j]]["資金流向(億)"])
    total_list.append(name_list)
    flow_list.append(flow)
grouped["上榜個股"] = total_list
grouped["資金流向(億)"] = flow_list
grouped['上榜個股'] = grouped['上榜個股'].apply(lambda x: ', '.join(x))
grouped = grouped.sort_values(by='平均漲幅%', ascending=False)

columns_to_format = ['平均漲幅%', '領漲漲幅%', "資金流向(億)"]
grouped[columns_to_format] = grouped[columns_to_format].apply(lambda x: x.apply(lambda y: '{:.2f}'.format(y)))
r = grouped
not_grouped = grouped[grouped["檔數"] == 1] # 只有一檔上榜 (個別表現)
grouped = grouped[grouped["檔數"] > 1] # 超過一檔上榜 (族群性佳)
not_grouped = not_grouped.style.applymap(set_color_group, subset=['平均漲幅%'])
grouped = grouped.style.applymap(set_color_group, subset=['平均漲幅%'])

# %%
df
# Out:
#      排名   商品     族群       成交   60日高點      總量    估計量   10日均量  月營收YoY  投信連買天數  \
# 0     1   鴻海  AI伺服器   156.00   159.0  191546     --  113803   11.80       2
# 1     2  台積電   先進製程   783.00   820.0   39315     --   49740   34.25       2
# 2     3   大同     重電    68.40    69.1  204600     --  237194   -8.86       1
# 3     4  長榮航     航運    34.55    32.7  385157     --   91554    8.29       7
# 4     5   廣達  AI伺服器   260.50   298.0   43989     --   36206    9.65       0
# ..  ...  ...    ...      ...     ...     ...    ...     ...     ...     ...
# 95   96   華通     衛星    74.30    83.5   14233     --   17374   19.07      14
# 96   97  富世達     軸承   733.00   896.0    1335     --    1867   37.18       1
# 97   98   信驊   傳輸IC  2980.00  3405.0     302    355     329   58.99       0
# 98   99   至上    記憶體    85.10    86.6   10526  11592   14274  168.40      12
# 99  100  永信建     營建   162.50   173.5    5331   5782    2866  102.41       0
#
#     資金流向(億)   內外盤比   漲幅%
# 0     76.39  63.08  8.33
# 1    105.57  67.25  3.85
# 2      7.73  52.78  6.71
# 3     43.91  66.76  5.98
# 4     43.46  69.23  9.92
# ..      ...    ...   ...
# 95     0.15  50.73  1.92
# 96     2.48  62.55  5.47
# 97     0.85  54.70  2.76
# 98     1.85  60.38  3.65
# 99    -3.81  28.64 -6.34
#
# [100 rows x 13 columns]

# %%
# 創高創量 ) & (df["估計量"].astype(int) > df["10日均量"]*1.5)
new_high = df[df["成交"].astype(float) > df["60日高點"].astype(float)]
new_high.reset_index(drop=True)
# Out:
#    排名   商品    族群      成交  60日高點      總量    估計量  10日均量  月營收YoY  投信連買天數  \
# 0   4  長榮航    航運   34.55   32.7  385157     --  91554    8.29       7
# 1  35  昇達科    衛星  196.50  182.5   12103     --   2671    2.31       0
# 2  42   國巨  被動元件  624.00  622.0    3380     --   3049   11.30       3
# 3  56   矽統    其他   69.30   69.2   22547  24194  90281  -20.20       0
# 4  66   南港    營建   53.50   53.3   24157  25515  25499   17.58       0
# 5  68   山富    旅遊  147.50  135.0    9391  10093   1771  180.04       0
# 6  72   雄獅    旅遊  150.50  144.5    8444   9212   3510   81.57       0
# 7  94   碩天    儲能  260.00  252.0    3663   4022   1956  -11.03       5
#
#    資金流向(億)   內外盤比   漲幅%
# 0    43.91  66.76  5.98
# 1     5.41  61.72  9.47
# 2     8.26  69.76  2.80
# 3    -0.10  49.67  7.44
# 4    -0.53  47.96  0.38
# 5     3.67  63.91  9.26
# 6     2.48  59.86  4.15
# 7     3.16  67.04  6.56

# %%
top_20 = df.head(20)
columns_to_format = ['成交', '60日高點', '月營收YoY', "資金流向(億)", "內外盤比", "漲幅%"]
top_20[columns_to_format] = top_20[columns_to_format].apply(lambda x: x.apply(lambda y: '{:.2f}'.format(y)))
top_20.style.applymap(set_color_per, subset=['漲幅%'])
# Out:
# <style type="text/css">
# #T_38632_row0_col12, #T_38632_row2_col12, #T_38632_row3_col12, #T_38632_row4_col12, #T_38632_row5_col12, #T_38632_row7_col12, #T_38632_row9_col12, #T_38632_row10_col12, #T_38632_row16_col12, #T_38632_row18_col12, #T_38632_row19_col12 {
#   background-color: pink;
# }
# #T_38632_row1_col12, #T_38632_row6_col12, #T_38632_row8_col12, #T_38632_row11_col12, #T_38632_row12_col12, #T_38632_row13_col12, #T_38632_row14_col12, #T_38632_row15_col12, #T_38632_row17_col12 {
#   background-color: white;
# }
# </style>
# <table id="T_38632">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38632_level0_col0" class="col_heading level0 col0" >排名</th>
#       <th id="T_38632_level0_col1" class="col_heading level0 col1" >商品</th>
#       <th id="T_38632_level0_col2" class="col_heading level0 col2" >族群</th>
#       <th id="T_38632_level0_col3" class="col_heading level0 col3" >成交</th>
#       <th id="T_38632_level0_col4" class="col_heading level0 col4" >60日高點</th>
#       <th id="T_38632_level0_col5" class="col_heading level0 col5" >總量</th>
#       <th id="T_38632_level0_col6" class="col_heading level0 col6" >估計量</th>
#       <th id="T_38632_level0_col7" class="col_heading level0 col7" >10日均量</th>
#       <th id="T_38632_level0_col8" class="col_heading level0 col8" >月營收YoY</th>
#       <th id="T_38632_level0_col9" class="col_heading level0 col9" >投信連買天數</th>
#       <th id="T_38632_level0_col10" class="col_heading level0 col10" >資金流向(億)</th>
#       <th id="T_38632_level0_col11" class="col_heading level0 col11" >內外盤比</th>
#       <th id="T_38632_level0_col12" class="col_heading level0 col12" >漲幅%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38632_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38632_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_38632_row0_col1" class="data row0 col1" >鴻海</td>
#       <td id="T_38632_row0_col2" class="data row0 col2" >AI伺服器</td>
#       <td id="T_38632_row0_col3" class="data row0 col3" >156.00</td>
#       <td id="T_38632_row0_col4" class="data row0 col4" >159.00</td>
#       <td id="T_38632_row0_col5" class="data row0 col5" >191546</td>
#       <td id="T_38632_row0_col6" class="data row0 col6" >--</td>
#       <td id="T_38632_row0_col7" class="data row0 col7" >113803</td>
#       <td id="T_38632_row0_col8" class="data row0 col8" >11.80</td>
#       <td id="T_38632_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_38632_row0_col10" class="data row0 col10" >76.39</td>
#       <td id="T_38632_row0_col11" class="data row0 col11" >63.08</td>
#       <td id="T_38632_row0_col12" class="data row0 col12" >8.33</td>
#     </tr>
#     <tr>
#       <th id="T_38632_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38632_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_38632_row1_col1" class="data row1 col1" >台積電</td>
#       <td id="T_38632_row1_col2" class="data row1 col2" >先進製程</td>
#       <td id="T_38632_row1_col3" class="data row1 col3" >783.00</td>
#       <td id="T_38632_row1_col4" class="data row1 col4" >820.00</td>
#       <td id="T_38632_row1_col5" class="data row1 col5" >39315</td>
#       <td id="T_38632_row1_col6" class="data row1 col6" >--</td>
#       <td id="T_38632_row1_col7" class="data row1 col7" >49740</td>
#       <td id="T_38632_row1_col8" class="data row1 col8" >34.25</td>
#       <td id="T_38632_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_38632_row1_col10" class="data row1 col10" >105.57</td>
#       <td id="T_38632_row1_col11" class="data row1 col11" >67.25</td>
#       <td id="T_38632_row1_col12" class="data row1 col12" >3.85</td>
#     </tr>
#     <tr>
#       <th id="T_38632_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38632_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_38632_row2_col1" class="data row2 col1" >大同</td>
#       <td id="T_38632_row2_col2" class="data row2 col2" >重電</td>
#       <td id="T_38632_row2_col3" class="data row2 col3" >68.40</td>
#       <td id="T_38632_row2_col4" class="data row2 col4" >69.10</td>
#       <td id="T_38632_row2_col5" class="data row2 col5" >204600</td>
#       <td id="T_38632_row2_col6" class="data row2 col6" >--</td>
#       <td id="T_38632_row2_col7" class="data row2 col7" >237194</td>
#       <td id="T_38632_row2_col8" class="data row2 col8" >-8.86</td>
#       <td id="T_38632_row2_col9" class="data row2 col9" >1</td>
#       <td id="T
row6_col0" class="data row6 col0" >7</td>
#       <td id="T_38632_row6_col1" class="data row6 col1" >華城</td>
#       <td id="T_38632_row6_col2" class="data row6 col2" >重電</td>
#       <td id="T_38632_row6_col3" class="data row6 col3" >854.00</td>
#       <td id="T_38632_row6_col4" class="data row6 col4" >955.00</td>
#       <td id="T_38632_row6_col5" class="data row6 col5" >11990</td>
#       <td id="T_38632_row6_col6" class="da

# %%
grouped
# Out:
# <style type="text/css">
# #T_876da_row0_col1, #T_876da_row1_col1, #T_876da_row2_col1, #T_876da_row3_col1, #T_876da_row4_col1, #T_876da_row5_col1, #T_876da_row6_col1, #T_876da_row7_col1, #T_876da_row8_col1 {
#   background-color: lightcoral;
# }
# #T_876da_row9_col1, #T_876da_row10_col1, #T_876da_row11_col1, #T_876da_row12_col1, #T_876da_row13_col1, #T_876da_row14_col1, #T_876da_row15_col1, #T_876da_row16_col1, #T_876da_row17_col1, #T_876da_row18_col1, #T_876da_row19_col1 {
#   background-color: pink;
# }
# #T_876da_row20_col1, #T_876da_row21_col1, #T_876da_row22_col1, #T_876da_row23_col1, #T_876da_row24_col1 {
#   background-color: white;
# }
# #T_876da_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_876da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_876da_level0_col0" class="col_heading level0 col0" >檔數</th>
#       <th id="T_876da_level0_col1" class="col_heading level0 col1" >平均漲幅%</th>
#       <th id="T_876da_level0_col2" class="col_heading level0 col2" >領漲</th>
#       <th id="T_876da_level0_col3" class="col_heading level0 col3" >領漲漲幅%</th>
#       <th id="T_876da_level0_col4" class="col_heading level0 col4" >上榜個股</th>
#       <th id="T_876da_level0_col5" class="col_heading level0 col5" >資金流向(億)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >族群</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_876da_level0_row0" class="row_heading level0 row0" >機殼</th>
#       <td id="T_876da_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_876da_row0_col1" class="data row0 col1" >9.91</td>
#       <td id="T_876da_row0_col2" class="data row0 col2" >勤誠</td>
#       <td id="T_876da_row0_col3" class="data row0 col3" >9.92</td>
#       <td id="T_876da_row0_col4" class="data row0 col4" >勤誠, 晟銘電</td>
#       <td id="T_876da_row0_col5" class="data row0 col5" >8.90</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row1" class="row_heading level0 row1" >散熱</th>
#       <td id="T_876da_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_876da_row1_col1" class="data row1 col1" >8.37</td>
#       <td id="T_876da_row1_col2" class="data row1 col2" >雙鴻</td>
#       <td id="T_876da_row1_col3" class="data row1 col3" >9.99</td>
#       <td id="T_876da_row1_col4" class="data row1 col4" >奇鋐, 雙鴻, 高力, 健策, 廣運</td>
#       <td id="T_876da_row1_col5" class="data row1 col5" >6.17</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row2" class="row_heading level0 row2" >ABF</th>
#       <td id="T_876da_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_876da_row2_col1" class="data row2 col1" >7.84</td>
#       <td id="T_876da_row2_col2" class="data row2 col2" >欣興</td>
#       <td id="T_876da_row2_col3" class="data row2 col3" >10.00</td>
#       <td id="T_876da_row2_col4" class="data row2 col4" >欣興, 南電</td>
#       <td id="T_876da_row2_col5" class="data row2 col5" >3.67</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row3" class="row_heading level0 row3" >AI伺服器</th>
#       <td id="T_876da_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_876da_row3_col1" class="data row3 col1" >7.07</td>
#       <td id="T_876da_row3_col2" class="data row3 col2" >廣達</td>
#       <td id="T_876da_row3_col3" class="data row3 col3" >9.92</td>
#       <td id="T_876da_row3_col4" class="data row3 col4" >廣達, 緯創, 緯穎, 技嘉, 英業達, 鴻海</td>
#       <td id="T_876da_row3_col5" class="data row3 col5" >76.39</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row4" class="row_heading level0 row4" >神盾集團</th>
#       <td id="T_876da_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_876da_row4_col1" class="data row4 col1" >6.82</td>
#       <td id="T_876da_row4_col2" class="data row4 col2" >神盾</td>
#       <td id="T_876da_row4_col3" class="data row4 col3" >9.96</td>
#       <td id="T_876da_row4_col4" class="data row4 col4" >神盾, 安國</td>
#       <td id="T_876da_row4_col5" class="data row4 col5" >2.07</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row5" class="row_heading level0 row5" >旅遊</th>
#       <td id="T_876da_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_876da_row5_col1" class="data row5 col1" >6.71</td>
#       <td id="T_876da_row5_col2" class="data row5 col2" >山富</td>
#       <td id="T_876da_row5_col3" class="data row5 col3" >9.26</td>
#       <td id="T_876da_row5_col4" class="data row5 col4" >雄獅, 山富</td>
#       <td id="T_876da_row5_col5" class="data row5 col5" >3.67</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row6" class="row_heading level0 row6" >半導體設備</th>
#       <td id="T_876da_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_876da_row6_col1" class="data row6 col1" >5.92</td>
#       <td id="T_876da_row6_col2" class="data row6 col2" >萬潤</td>
#       <td id="T_876da_row6_col3" class="data row6 col3" >9.66</td>
#       <td id="T_876da_row6_col4" class="data row6 col4" >萬潤, 辛耘</td>
#       <td id="T_876da_row6_col5" class="data row6 col5" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row7" class="row_heading level0 row7" >衛星</th>
#       <td id="T_876da_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_876da_row7_col1" class="data row7 col1" >5.70</td>
#       <td id="T_876da_row7_col2" class="data row7 col2" >昇達科</td>
#       <td id="T_876da_row7_col3" class="data row7 col3" >9.47</td>
#       <td id="T_876da_row7_col4" class="data row7 col4" >華通, 昇達科</td>
#       <td id="T_876da_row7_col5" class="data row7 col5" >5.41</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row8" class="row_heading level0 row8" >手機IC</th>
#       <td id="T_876da_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_876da_row8_col1" class="data row8 col1" >5.34</td>
#       <td id="T_876da_row8_col2" class="data row8 col2" >達發</td>
#       <td id="T_876da_row8_col3" class="data row8 col3" >6.81</td>
#       <td id="T_876da_row8_col4" class="data row8 col4" >聯發科, 達發, 瑞昱</td>
#       <td id="T_876da_row8_col5" class="data row8 col5" >-1.33</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row9" class="row_heading level0 row9" >傳輸IC</th>
#       <td id="T_876da_row9_col0" class="data row9 col0" >3</td>
#       <td id="T_876da_row9_col1" class="data row9 col1" >4.66</td>
#       <td id="T_876da_row9_col2" class="data row9 col2" >祥碩</td>
#       <td id="T_876da_row9_col3" class="data row9 col3" >7.99</td>
#       <td id="T_876da_row9_col4" class="data row9 col4" >譜瑞-KY, 祥碩, 信驊</td>
#       <td id="T_876da_row9_col5" class="data row9 col5" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row10" class="row_heading level0 row10" >儲能</th>
#       <td id="T_876da_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_876da_row10_col1" class="data row10 col1" >4.37</td>
#       <td id="T_876da_row10_col2" class="data row10 col2" >碩天</td>
#       <td id="T_876da_row10_col3" class="data row10 col3" >6.56</td>
#       <td id="T_876da_row10_col4" class="data row10 col4" >台達電, 光寶科, 碩天</td>
#       <td id="T_876da_row10_col5" class="data row10 col5" >3.16</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row11" class="row_heading level0 row11" >記憶體</th>
#       <td id="T_876da_row11_col0" class="data row11 col0" >4</td>
#       <td id="T_876da_row11_col1" class="data row11 col1" >4.28</td>
#       <td id="T_876da_row11_col2" class="data row11 col2" >威剛</td>
#       <td id="T_876da_row11_col3" class="data row11 col3" >5.08</td>
#       <td id="T_876da_row11_col4" class="data row11 col4" >群聯, 威剛, 南亞科, 至上</td>
#       <td id="T_876da_row11_col5" class="data row11 col5" >1.85</td>
#     </tr>
#     <tr>
#       <th id="T_876da_level0_row12" class="row_heading level0 row12" >航運</th>
#       <td id="T_876da_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_876da_row12_col1" class="data row12 col1" >4.24</td>
#       <td id="T_876da_row12_col2" class="data row12 col2" >長榮航</td>
#       <td id="T_876da_row12_col3" class="data row12 col3" >5.98</td>
#       <td i

# %%
not_grouped
# Out:
# <style type="text/css">
# #T_e1c39_row0_col1, #T_e1c39_row1_col1, #T_e1c39_row2_col1, #T_e1c39_row3_col1, #T_e1c39_row4_col1, #T_e1c39_row5_col1 {
#   background-color: lightcoral;
# }
# #T_e1c39_row6_col1, #T_e1c39_row7_col1, #T_e1c39_row8_col1, #T_e1c39_row9_col1, #T_e1c39_row10_col1, #T_e1c39_row11_col1, #T_e1c39_row12_col1 {
#   background-color: pink;
# }
# #T_e1c39_row13_col1, #T_e1c39_row14_col1 {
#   background-color: white;
# }
# </style>
# <table id="T_e1c39">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1c39_level0_col0" class="col_heading level0 col0" >檔數</th>
#       <th id="T_e1c39_level0_col1" class="col_heading level0 col1" >平均漲幅%</th>
#       <th id="T_e1c39_level0_col2" class="col_heading level0 col2" >領漲</th>
#       <th id="T_e1c39_level0_col3" class="col_heading level0 col3" >領漲漲幅%</th>
#       <th id="T_e1c39_level0_col4" class="col_heading level0 col4" >上榜個股</th>
#       <th id="T_e1c39_level0_col5" class="col_heading level0 col5" >資金流向(億)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >族群</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1c39_level0_row0" class="row_heading level0 row0" >機器人</th>
#       <td id="T_e1c39_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e1c39_row0_col1" class="data row0 col1" >9.90</td>
#       <td id="T_e1c39_row0_col2" class="data row0 col2" >廣明</td>
#       <td id="T_e1c39_row0_col3" class="data row0 col3" >9.90</td>
#       <td id="T_e1c39_row0_col4" class="data row0 col4" >廣明</td>
#       <td id="T_e1c39_row0_col5" class="data row0 col5" >4.88</td>
#     </tr>
#     <tr>
#       <th id="T_e1c39_level0_row1" class="row_heading level0 row1" >PMIC</th>
#       <td id="T_e1c39_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_e1c39_row1_col1" class="data row1 col1" >9.88</td>
#       <td id="T_e1c39_row1_col2" class="data row1 col2" >矽力*-KY</td>
#       <td id="T_e1c39_row1_col3" class="data row1 col3" >9.88</td>
#       <td id="T_e1c39_row1_col4" class="data row1 col4" >矽力*-KY</td>
#       <td id="T_e1c39_row1_col5" class="data row1 col5" >8.87</td>
#     </tr>
#     <tr>
#       <th id="T_e1c39_level0_row2" class="row_heading level0 row2" >連接器</th>
#       <td id="T_e1c39_row2_col0" class="data row2 col0" >1</td>
#       <td id="T
row9_col0" class="data row9 col0" >1</td>
#       <td id="T_e1c39_row9_col1" class="data row9 col1" >3.28</td>
#       <td id="T_e1c39_row9_col2" class="data row9 col2" >大立光</td>
#       <td id="T_e1c39_row9_col3" class="data row9 col3" >3.28</td>
#       <td id="T_e1c39_row9_col4" class="data row9 col4" >大立光</td>
#       <td id="T_e1c39_row9_col5" class="data row9 col5" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_e1c39_level0_row10" class="row_heading level0 row10" >DDIC</th>
#       <td id="T_e1c39_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_e1c39_row10_col1" class="data row10 col1" >3.09</td>
#       <td id="T_e1c39_row10_col2" class="data row10 col2" >聯詠</td>
#       <td id="T_e1c39_row10_col3" class="data row10 col3" >3.09</td>
#       <td id="T_e1c39_row10_col4" class="data row10 col4" >聯詠</td>
#       <td id="T_e1c39_row10_col5" class="data row10 col5" >-2.31</td>
#     </tr>
#     <tr>
#       <th id="T_e1c39_level0_row11" class="row_heading level0 row11" >被動元件</th>
#       <td id="T_e1c39_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_e1c39_row11_col1" class="data row11 col1" >2.80</td>
#       <td id="T_e1c39_row11_col2" class="data row11 col2" >國巨</td>
#       <td id="T_e1c39_row11_col3" class="data row11 col3" >2.80</td>
#       <td id="T_e1c39_row11_col4" class="data row11 col4" >國巨</td>
#       <td id="T_e1c39_row11_col5" class="data row11 col5" >8.26</td>
#     </tr>
#     <tr>
#       <th id="T_e1c39_level0_row12" class="row_heading level0 row12" >半導體廠務</th>
#       <td id="T_e1c39_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_e1c39_row12_col1" class="data row12 col1" >2.74</td>
#       <td id="T_e1c39_row12_col2" class="data row12 col2" >漢唐</td>
#       <td id="T_e1c39_row12_col3" class="data row12 col3" >2.74</td>
#       <td id="T_e1c39_row12_col4" class="data row12 col4" >漢唐</td>
#       <td id="T_e1c39_row12_col5" class="data row12 col5" >3.23</td>
#     </tr>
#     <tr>
#       <th id="T_e1c39_level0_row13" class="row_heading level0 row13" >網通</th>
#       <td id="T_e1c39_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_e1c39_row13_col1" class="data row13 col

# %%
search = df[df["族群"] == "其他"]
search = search.sort_values(by="漲幅%", ascending=False).reset_index(drop=True)
columns_to_format = ["成交", "60日高點", "漲幅%", '月營收YoY', '資金流向(億)', "內外盤比"]
search[columns_to_format] = search[columns_to_format].apply(lambda x: x.apply(lambda y: '{:.2f}'.format(y)))
search.style.applymap(set_color_rank, subset=["排名"])
# Out:
# <style type="text/css">
# #T_8d4fc_row0_col0, #T_8d4fc_row1_col0, #T_8d4fc_row2_col0, #T_8d4fc_row3_col0, #T_8d4fc_row4_col0, #T_8d4fc_row6_col0, #T_8d4fc_row7_col0 {
#   background-color: white;
# }
# #T_8d4fc_row5_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8d4fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d4fc_level0_col0" class="col_heading level0 col0" >排名</th>
#       <th id="T_8d4fc_level0_col1" class="col_heading level0 col1" >商品</th>
#       <th id="T_8d4fc_level0_col2" class="col_heading level0 col2" >族群</th>
#       <th id="T_8d4fc_level0_col3" class="col_heading level0 col3" >成交</th>
#       <th id="T_8d4fc_level0_col4" class="col_heading level0 col4" >60日高點</th>
#       <th id="T_8d4fc_level0_col5" class="col_heading level0 col5" >總量</th>
#       <th id="T_8d4fc_level0_col6" class="col_heading level0 col6" >估計量</th>
#       <th id="T_8d4fc_level0_col7" class="col_heading level0 col7" >10日均量</th>
#       <th id="T_8d4fc_level0_col8" class="col_heading level0 col8" >月營收YoY</th>
#       <th id="T_8d4fc_level0_col9" class="col_heading level0 col9" >投信連買天數</th>
#       <th id="T_8d4fc_level0_col10" class="col_heading level0 col10" >資金流向(億)</th>
#       <th id="T_8d4fc_level0_col11" class="col_heading level0 col11" >內外盤比</th>
#       <th id="T_8d4fc_level0_col12" class="col_heading level0 col12" >漲幅%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d4fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d4fc_row0_col0" class="data row0 col0" >56</td>
#       <td id="T_8d4fc_row0_col1" class="data row0 col1" >矽統</td>
#       <td id="T_8d4fc_row0_col2" class="data row0 col2" >其他</td>
#       <td id="T_8d4fc_row0_col3" class="data row0 col3" >69.30</td>
#       <td id="T_8d4fc_row0_col4" class="data row0 col4" >69.20</td>
#       <td id="T_8d4fc_row0_col5" class="data row0 col5" >22547</td>
#       <td id="T_8d4fc_row0_col6" class="data row0 col6" >24194</td>
#       <td id="T_8d4fc_row0_col7" class="data row0 col7" >90281</td>
#       <td id="T_8d4fc_row0_col8" class="data row0 col8" >-20.20</td>
#       <td id="T_8d4fc_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_8d4fc_row0_col10" class="data row0 col10" >-0.10</td>
#       <td id="T_8d4fc_row0_col11" class="data row0 col11" >49.67</td>
#       <td id="T_8d4fc_row0_col12" class="data row0 col12" >7.44</td>
#     </tr>
#     <tr>
#       <th id="T_8d4fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d4fc_row1_col0" class="data row1 col0" >38</td>
#       <td id="T_8d4fc_row1_col1" class="data row1 col1" >材料-KY</td>
#       <td id="T_8d4fc_row1_col2" class="data row1 col2" >其他</td>
#       <td id="T_8d4fc_row1_col3" class="data row1 col3" >778.00</td>
#       <td id="T_8d4fc_row1_col4" class="data row1 col4" >1050.00</td>
#       <td id="T_8d4fc_row1_col5" class="data row1 col5" >2989</td>
#       <td id="T_8d4fc_row1_col6" class="data row1 col6" >--</td>
#       <td id="T_8d4fc_row1_col7" class="data row1 col7" >2521</td>
#       <td id="T_8d4fc_row1_col8" class="data row1 col8" >109.27</td>
#       <td id="T_8d4fc_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_8d4fc_row1_col10" class="data row1 col10" >0.76</td>
#       <td id="T_8d4fc_row1_col11" class="data row1 col11" >51.65</td>
#       <td id="T_8d4fc_row1_col12" class="data row1 col12" >6.14</td>
#     </tr>
#     <tr>
#       <th id="T_8d4fc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d4fc_row2_col0" class="data row2 col0" >81</td>
#       <td id="T_8d4fc_row2_col1" class="data row2 col1" >一詮</td>
#       <td id="T_8d4fc_row2_col2" class="data row2 col2" >其他</td>
#       <td id="T_8d4fc_row2_col3" class="data row2 col3" >69.60</td>
#       <td id="T_8d4fc_row2_col4" class="data row2 col4" >75.00</td>
#       <td id="T_8d4fc_row2_col5" class="data row2 col5" >16804</td>
#       <td id="T_8d4fc_row2_col6" class="data row2 col6" >19471</td>
#       <td id="T_8d4fc_row2_col7" class="data row2 col7" >21074</td>
#       <td id="T_8d4fc_row2_col8" class="data row2 col8" >1.14</td>
#       <td id="T_8d4fc_row2_col9" class="data row2 col9" >4</td>
#       <td id="T_8d4fc_row2_col10" class="data row2 col10" >1.54</td>
#       <td id="T_8d4fc_row2_col11" class="data row2 col11" >56.58</td>
#       <td id="T_8d4fc_row2_col12" class="data row2 col12" >5.45</td>
#     </tr>
#     <tr>
#       <th id="T_8d4fc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8
c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8d4fc_row6_col0" class="data row6 col0" >65</td>
#       <td id="T_8d4fc_row6_col1" class="data row6 col1" >中華電</td>
#       <td id="T_8d4fc_row6_col2" class="data row6 col2" >其他</td>
#       <td id="T_8d4fc_row6_col3" class="data row6 col3" >124.00</td>
#       <td id="T_8d4fc_row6_col4" class="data row6 col4" >127.00</td>
#       <td id="T_8d4fc_row6_col5" class="data row6 col5" >11142</td>
#       <td id="T_8d4fc_row6_col6" class="data row6 col6" >13562</td>
#       <td id="T_8d4fc_row6_col7" class="data row6 col7" >11599</td>
#       <td id="T_8d4fc_row6_col8" class="data row6 col8" >-0.94</td>
#       <td id="T_8d4fc_row6_col9" class="data row6 col9" >5</td>
#       <td id="T_8d4fc_row6_col10" class="data

# %%
trust = df[df["投信連買天數"] >= 5]
trust = trust.sort_values(by='投信連買天數', ascending=False).reset_index(drop=True)
trust#.style.applymap(set_color_per, subset=['漲幅%'])
# Out:
#     排名    商品       族群      成交   60日高點      總量    估計量  10日均量  月營收YoY  投信連買天數  \
# 0   31    聯詠     DDIC  601.00  630.00    4437     --   5318   -6.60      45
# 1   36    旺矽  半導體測試介面  402.50  414.00    5880     --   5571   19.56      19
# 2   85   中光電       軍工   95.10  107.50   11510  12300  18531  -11.20      15
# 3   96    華通       衛星   74.30   83.50   14233     --  17374   19.07      14
# 4   95    國產       營建   43.90   48.25   25187     --  17033  -12.11      13
# 5   99    至上      記憶體   85.10   86.60   10526  11592  14274  168.40      12
# 6   78  京元電子    半導體封裝   96.10  116.50   12449  14396  14791    7.17       9
# 7   13   中興電       重電  194.50  212.00   37787     --  83027   12.10       9
# 8   23    勤誠       機殼  288.00  312.50   12547     --   6243   54.41       8
# 9    4   長榮航       航運   34.55   32.70  385157     --  91554    8.29       7
# 10  73    世界     成熟製程   84.90   90.80   14788  17841  11287   44.82       7
# 11  80    達發     手機IC  674.00  704.00    1912     --   1532   17.82       6
# 12  71    東元       重電   59.30   61.10   21082  23287  46619  -16.74       6
# 13  40    聯電     成熟製程   50.20   53.30   46648     --  69077    2.70       6
# 14  12    士電       重電  316.00  344.50   25799     --  26353   -1.42       5
# 15  79   光寶科       儲能   98.40  123.50   12032  13880  19024  -14.97       5
# 16  94    碩天       儲能  260.00  252.00    3663   4022   1956  -11.03       5
# 17  65   中華電       其他  124.00  127.00   11142  13562  11599   -0.94       5
#
#     資金流向(億)   內外盤比   漲幅%
# 0     -2.31  45.64  3.09
# 1      5.29  61.15  4.27
# 2      0.61  52.81  5.08
# 3      0.15  50.73  1.92
# 4     -1.36  43.97 -5.89
# 5      1.85  60.38  3.65
# 6      0.16  50.67  4.12
# 7      5.98  54.11  3.18
# 8     19.11  77.07  9.92
# 9     43.91  66.76  5.98
# 10     2.63  60.53  3.16
# 11     2.53  60.03  6.81
# 12     1.70  56.75  1.72
# 13     6.79  64.64  3.08
# 14     7.12  54.45  2.43
# 15     2.63  61.15  4.02
# 16     3.16  67.04  6.56
# 17    -3.51  37.36 -0.80
