# %%
def set_color_group(val): # 族群平均漲幅
    if float(val) > 5:
        color = "lightcoral"
    elif 2.5 <= float(val) <= 5:
        color = 'pink'
    elif -5 <= float(val) < -2:
        color = 'lightgreen'
    elif float(val) < -5:
        color = 'green'
    else:
        color = 'white'
    return f'background-color: {color}'

def set_color_rank(val): # 
    if val <= 20:
        color = 'yellow'
    else:
        color = 'white'
    return f'background-color: {color}'

def set_color_per(val):
    if float(val) >= 4:
        color = 'pink'
    elif float(val) <= -4:
        color = "lightgreen"
    else:
        color = 'white'
    return f'background-color: {color}'

def process_cell(cell):
    match = re.match(r'([\d.]+)(億|萬)?', cell)
    if match:
        num = float(match.group(1)) 
        unit = match.group(2)  
        if unit == '萬':
            return round(num*0.0001, 2)
        elif unit == '億':
            return round(num, 2)
    else:
        return cell

# %%
categories = {
    # "權值": ["台積電", "鴻海", "聯發科", "廣達", "台達電", "日月光投控", "聯電", "富邦金", "國泰金", "中華電", "台泥"],
    # "IGNORE": ["中華電", "台泥"],
    "重電": ["華城", "中興電", "士電", "亞力", "大同", "東元", "洋華"],
    "電纜": ["大亞", "華榮", "宏泰", "華電", "華興", "合機", "華新", "億泰", "榮星"],
    "綠能": ["世紀鋼", "森崴能源", "上緯投控", "樂事綠能"],
    "儲能": ["台達電", "光寶科", "康舒", "碩天", "盛達"],
    "太陽能模組": ["元晶", "聯合再生", "茂迪"],
    "水資源": ["國統", "山林水", "中工", "力麒", "欣陸", "中鼎", "中宇"],
    "先進製程": ["台積電"],
    "成熟製程": ["聯電", "世界", "力積電"],
    "半導體設備": ["萬潤", "弘塑", "志聖", "家登", "辛耘", "中砂", "帆宣", "公準", "蔚華科", "大量", "均豪", "均華", "大量", "光洋科"],
    "半導體廠務": ["亞翔", "信紘科", "聖暉*", "漢唐", "洋基工程", "崇越", "牧德"],
    "半導體檢測": ["閎康", "汎銓", "宜特"],
    "半導體化材": ["上品", "達興材料", "勝一", "三福化", "晶呈科技"],
    "半導體矽晶圓": ["環球晶", "台勝科", "中美晶", "合晶"],
    "半導體測試介面": ["旺矽", "穎崴", "精測"],
    "半導體封裝": ["日月光投控", "京元電子"],
    "記憶體": ["群聯", "威剛", "十銓", "宇瞻", "南亞科", "華邦電", "晶豪科", "創見", "至上", "旺宏", "南茂", "力成"],
    "手機IC": ["聯發科", "達發", "瑞昱"],
    "DDIC": ["聯詠", "瑞鼎", "矽創", "天鈺", "敦泰"],
    "PMIC": ["矽力*-KY", "茂達", "力智", "致新"],
    "傳輸IC": ["譜瑞", "祥碩", "信驊"],
    "顯卡": ["撼訊", "麗臺"],
    "連接器": ["嘉澤", "宏致", "良維", "信音"],
    "AI伺服器": ["廣達", "緯創", "緯穎", "技嘉", "英業達", "鴻海"],
    "IP": ["世芯-KY", "創意", "智原", "力旺", "M31",  "愛普*"],
    "中國IC / IP": ["威盛", "金麗科", "晶心科"],
    "神盾集團": ["神盾", "安國", "安格", "驊訊", "芯鼎", "迅杰"],
    "伺服器滑軌": ["川湖", "南俊國際"],
    "散熱": ["奇鋐", "雙鴻", "高力", "建準", "健策", "尼德科超眾", "AMAX-KY", "廣運", "尼得科超眾"],
    "機殼": ["迎廣", "勤誠", "振發", "旭品", "營邦", "晟銘電"],
    "光通訊": ["聯亞", "統新", "光環", "華星光", "訊芯-KY", "聯均", "上詮", "台通", "光聖", "前鼎", "眾達-KY", "波若威", "創威"],
    "軸承": ["兆利", "富世達", "新日興", "信錦"],
    "光學": ["大立光", "玉晶光", "揚明光", "先進光", "亞光", "采鈺"],
    "軍工": ["漢翔", "亞航", "寶一", "雷虎", "邑錡", "中光電", "千附精密", "八貫", "精剛", "龍德造船", "台船", "長榮航太", "全訊"],
    "工業電腦": ["研華", "樺漢", "威強電", "研揚"],
    "機器人": ["所羅門", "廣明", "百達-KY"],
    "生技": ["順藥", "保瑞", "台耀", "美時", "安克"],
    "PC": ["宏碁", "華碩", "微星", "仁寶", "義隆", "藍天"],
    "電子紙": ["元太", "振曜"],
    "PA": ["立積", "穩懋", "宏捷科", "全新", "耕興"],
    "GaN": ["漢磊", "嘉晶"],
    "ABF": ["欣興", "南電", "景碩"],
    "CCL / AI PCB": ["台光電", "台燿", "聯茂", "金居", "金像電"],
    "車用PCB": ["定穎投控", "健鼎", "敬鵬"],
    "衛星板": ["華通", "燿華", "新復興", "昇達科"],
    "車用電子": ["華孚", "胡連", "乙盛-KY", "新唐", "同欣電"],
    "車用AM": ["東陽", "堤維西", "耿鼎", "帝寶"],
    "營建": ["工信","興富發", "潤隆", "日勝生", "華固", "冠德", "長虹", "國產", "國建", "皇昌", "南港", "聯上", "皇普", "永信建", "華建", "三發地產", "櫻花建", "新美齊", "新潤", "愛山林", "亞昕", "坤悅", "晶悅", "昇陽", "富宇", "華友聯", "隆大", "富華新", "皇鼎"],
    "自行車": ["巨大", "美利達"],
    "被動元件": ["國巨", "華新科"],
    "網通": ["啟碁", "中磊", "智易", "智邦", "正文", "海華", "正基", "神準", "合勤控"],
    "成衣製鞋": ["聚陽", "儒鴻", "寶成", "豐泰", "鈺齊-KY"],
    "航運": ["華航", "長榮航"],
    "海運": ["長榮", "陽明", "萬海"],
    "散裝航": ["慧洋-KY", "裕民", "新興"],
    "面板": ["友達", "群創"],
    "金融": ["國泰金", "玉山金", "富邦金", "中信金", "新光金", "台新金", "元大金", "兆豐金"],
    "資安軟體": ["精誠", "敦陽科", "零壹", "宏碁資訊", "邁達特", "緯軟", "凌群"],
    "鋼鐵": ["中鴻", "大成鋼", "長榮鋼"],
    "遊戲": ["鈊象", "智冠", "大宇資", "華義"]
}

# %%
import pandas as pd
import re
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv(r"C:\Users\User\Downloads\Book1.csv")
基本_籌碼資料 = pd.read_csv(r"C:\Users\User\5. 看盤\投信月營收\2024-04-19 投信月營收.csv"); 基本_籌碼資料.drop(columns=["Unnamed: 0"], inplace=True)
df = pd.merge(df, 基本_籌碼資料, on='代碼', how='left')

df["排名"] = df.index + 1
new_column_order = ['排名'] + [col for col in df.columns if col != '排名']
df = df[new_column_order]

df['族群'] = ''
for index, row in df.iterrows():
    categorized = False
    for category, items in categories.items():
        if row['商品'] in items:
            df.at[index, '族群'] = category
            categorized = True 
            break
    if not categorized:
        df.at[index, '族群'] = "其他"

df["成交值"] = df["成交值"].apply(process_cell)
# df["成交值(億)"] = df["成交值"].str.replace("億", "").astype(float); df.drop(columns=["成交值"], inplace=True)
df["成交值(億)"] = df["成交值"]
df.drop(columns=["成交值"], inplace=True)
df["資金流向(億)"] = round((0.01*(2*df["內外盤比圖"]) - 1) * df["成交值(億)"], 2)
df["內外盤比"] = df["內外盤比圖"]; df.drop(columns=["內外盤比圖"], inplace=True)

df = df[["排名", "商品", "族群", "成交", "60日高點", "總量", "10日均量", "月營收YoY", "投信連買天數", "資金流向(億)", "內外盤比", "漲幅%"]]

# 族群
grouped = df[df['族群'] != '其他']
grouped = grouped.groupby('族群').agg({'商品': 'count', '漲幅%': 'mean'})
grouped.columns = ['檔數', '平均漲幅%']

max_increase_idx = df.groupby('族群')['漲幅%'].idxmax()
max_increase_rows = df.loc[max_increase_idx, ['族群', '商品', '漲幅%']]
max_increase_rows.set_index('族群', inplace=True)
grouped['領漲'] = max_increase_rows['商品']
grouped['領漲漲幅%'] = max_increase_rows['漲幅%']

total_list = []; flow_list = []
for i in range(len(grouped)):
    group_name = grouped.index[i]
    name_list = []
    flow = 0
    for j in range(len(categories[group_name])):
        if categories[group_name][j] in list(df["商品"]):
            name_list.append(categories[group_name][j])
            flow = float(df[df["商品"] == categories[group_name][j]]["資金流向(億)"])
    total_list.append(name_list)
    flow_list.append(flow)
grouped["上榜個股"] = total_list
grouped["資金流向(億)"] = flow_list
grouped['上榜個股'] = grouped['上榜個股'].apply(lambda x: ', '.join(x))
grouped = grouped.sort_values(by='平均漲幅%', ascending=False)

columns_to_format = ['平均漲幅%', '領漲漲幅%', "資金流向(億)"]
grouped[columns_to_format] = grouped[columns_to_format].apply(lambda x: x.apply(lambda y: '{:.2f}'.format(y)))
r = grouped
not_grouped = grouped[grouped["檔數"] == 1] # 只有一檔上榜 (個別表現)
grouped = grouped[grouped["檔數"] > 1] # 超過一檔上榜 (族群性佳)
not_grouped = not_grouped.style.applymap(set_color_group, subset=['平均漲幅%'])
grouped = grouped.style.applymap(set_color_group, subset=['平均漲幅%'])

# %%
# 創高
new_high = df[df["成交"].astype(float) > df["60日高點"].astype(float)]; new_high.reset_index(drop=True)
# Out:
#    排名     商品   族群     成交   60日高點      總量  10日均量  月營收YoY  投信連買天數  資金流向(億)  \
# 0  26   上緯投控   綠能  148.5  146.50   21721   8403   -2.57       8     2.92
# 1  33     南港   營建   50.7   50.00   57452  18072   17.58       0     1.54
# 2  48     華固   營建  161.0  149.50   13968   3277  -99.92       8     1.77
# 3  61  慧洋-KY  散裝航   69.2   66.70   25081   8490   30.05       2     3.97
# 4  69     長虹   營建  124.5  123.00   12035   5519  -60.31       9     0.87
# 5  78    群益證   其他   24.7   23.50   55340  22568   45.46       2     4.82
# 6  98    中石化   其他   10.2    9.93  113418  27079   17.04       0     3.15
#
#     內外盤比   漲幅%
# 0  54.40  2.41
# 1  52.58  1.40
# 2  54.06  7.69
# 3  61.46  4.37
# 4  52.87  1.22
# 5  67.84  5.11
# 6  63.57  3.98

# %%
top_20 = df.head(20)
columns_to_format = ['成交', '60日高點', '月營收YoY', "資金流向(億)", "內外盤比", "漲幅%"]
top_20[columns_to_format] = top_20[columns_to_format].apply(lambda x: x.apply(lambda y: '{:.2f}'.format(y)))
top_20.style.applymap(set_color_per, subset=['漲幅%'])
# Out:
# <style type="text/css">
# #T_6687e_row0_col11, #T_6687e_row2_col11, #T_6687e_row6_col11, #T_6687e_row8_col11, #T_6687e_row9_col11, #T_6687e_row18_col11, #T_6687e_row19_col11 {
#   background-color: white;
# }
# #T_6687e_row1_col11, #T_6687e_row3_col11, #T_6687e_row4_col11, #T_6687e_row5_col11, #T_6687e_row7_col11, #T_6687e_row10_col11, #T_6687e_row11_col11, #T_6687e_row12_col11, #T_6687e_row13_col11, #T_6687e_row14_col11, #T_6687e_row15_col11, #T_6687e_row16_col11, #T_6687e_row17_col11 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6687e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6687e_level0_col0" class="col_heading level0 col0" >排名</th>
#       <th id="T_6687e_level0_col1" class="col_heading level0 col1" >商品</th>
#       <th id="T_6687e_level0_col2" class="col_heading level0 col2" >族群</th>
#       <th id="T_6687e_level0_col3" class="col_heading level0 col3" >成交</th>
#       <th id="T_6687e_level0_col4" class="col_heading level0 col4" >60日高點</th>
#       <th id="T_6687e_level0_col5" class="col_heading level0 col5" >總量</th>
#       <th id="T_6687e_level0_col6" class="col_heading level0 col6" >10日均量</th>
#       <th id="T_6687e_level0_col7" class="col_heading level0 col7" >月營收YoY</th>
#       <th id="T_6687e_level0_col8" class="col_heading level0 col8" >投信連買天數</th>
#       <th id="T_6687e_level0_col9" class="col_heading level0 col9" >資金流向(億)</th>
#       <th id="T_6687e_level0_col10" class="col_heading level0 col10" >內外盤比</th>
#       <th id="T_6687e_level0_col11" class="col_heading level0 col11" >漲幅%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6687e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6687e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6687e_row0_col1" class="data row0 col1" >台積電</td>
#       <td id="T_6687e_row0_col2" class="data row0 col2" >先進製程</td>
#       <td id="T_6687e_row0_col3" class="data row0 col3" >742.00</td>
#       <td id="T_6687e_row0_col4" class="data row0 col4" >820.00</td>
#       <td id="T_6687e_row0_col5" class="data row0 col5" >46450</td>
#       <td id="T_6687e_row0_col6" class="data row0 col6" >51518</td>
#       <td id="T_6687e_row0_col7" class="data row0 col7" >34.25</td>
#       <td id="T_6687e_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_6687e_row0_col9" class="data row0 col9" >-43.67</td>
#       <td id="T_6687e_row0_col10" class="data row0 col10" >43.69</td>
#       <td id="T_6687e_row0_col11" class="data row0 col11" >-1.07</td>
#     </tr>
#     <tr>
#       <th id="T_6687e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6687e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6687e_row1_col1" class="data row1 col1" >大同</td>
#       <td id="T_6687e_row1_col2" class="data row1 col2" >重電</td>
#       <td id="T_6687e_row1_col3" class="data row1 col3" >65.40</td>
#       <td id="T_6687e_row1_col4" class="data row1 col4" >69.10</td>
#       <td id="T_6687e_row1_col5" class="data row1 col5" >349481</td>
#       <td id="T_6687e_row1_col6" class="data row1 col6" >195899</td>
#       <td id="T_6687e_row1_col7" class="data row1 col7" >-8.86</td>
#       <td id="T_6687e_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_6687e_row1_col9" class="data row1 col9" >-22.31</td>
#       <td id="T_6687e_row1_col10" class="data row1 col10" >45.41</td>
#       <td id="T_6687e_row1_col11" class="data row1 col11" >-5.35</td>
#     </tr>
#     <tr>
#       <th id="T_6687e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6687e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6687e_row2_col1" class="data row2 col1" >長榮</td>
#       <td id="T_6687e_row2_col2" class="data row2 col2" >海運</td>
#       <td id="T_6687e_row2_col3" class="data row2 col3" >174.00</td>
#       <td id="T_6687e_row2_col4" class="data row2 col4" >191.00</td>
#       <td id="T_6687e_row2_col5" class="data row2 col5" >64625</td>
#       <td id="T_6687e_row2_col6" class="data row2 col6" >29296</td>
#       <td id="T_6687e_row2_col7" class="data row2 col7" >37.46</td>
#       <td id="T_6687e_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_6687e_row2_col9" class="data row2 col9" >5.86</td>
#       <td id="T_6687e_row2_col10" class="data row2 col10" >52.55</td>
#       <td id="T_6687e_row2_col11" class="data row2 col11" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_6687e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6687e_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6687e_row3_col1" class="data row3 col1" >大亞</td>
#       <td id="T_6687e_row3_col2" class="data row3 col2" >電纜</td>
#       <td id="T_6687e_row3_col3" class="data row3 col3" >57.80</td>
#       <td id="T_6687e_row3_col4" class="data row3 col4" >64.70</td>
#       <td id="T_6687e_row3_col5" class="data row3 col5" >183557</td>
#       <td id="T_6687e_row3_col6" class="data row3 col6" >151710</td>
#       <td id="T_6687e_row3_col7" class="data row3 col7" >-5.26</td>
#       <td id="T_6687e_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_6687e_row3_col9" class="data row3 col9" >-29.58</td>
#       <td id="T_6687e_row3_col10" class="data row3 col10" >36.91</td>
#       <td id="T_6687e_row3_col11" class="data row3 col11" >-9.97</td>
#     </tr>
#     <tr>
#       <th id="T_6687e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6687e_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_6687e_row4_col1" class="data row4 col1" >奇鋐</td>
#       <td id="T_6687e_row4_col2" class="data row4 col2" >散熱</td>
#       <td id="T_6687e_row4_col3" class="data row4 col3" >567.00</td>
#       <td id="T_6687e_row4_col4" class="data row4 col4" >680.00</td>
#       <td id="T_6687e_row4_col5" class="data row4 col5" >18987</td>
#       <td id="T_6687e_row4_col6" class="data row4 col6" >17117</td>
#       <td id="T_6687e_row4_col7" class="data row4 col7" >6.60</td>
#       <td id="T_6687e_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_6687e_row4_col9" class="data row4 col9" >-21.53</td>
#       <td id="T_6687e_row4_col10" class="data row4 col10" >40.30</td>
#       <td id="T_6687e_row4_col11" class="data row4 col11" >-10.00</td>
#     </tr>
#     <tr>
#       <th id="T_6687e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6687e_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_6687e_row5_col1" class="data row5 col1" >華城</td>
#       <td id="T_6687e_row5_col2" class="data row5 col2" >重電</td>
#       <td id="T_6687e_row5_col3" class="data row5 col3" >824.00</td>
#       <td id="T_6687e_row5_col4" class="data row5 col4" >955.00</td>
#       <td id="T_6687e_row5_col5" class="data row5 col5" >11409</td>
#       <td id="T_6687e_row5_col6" class="data row5 col6" >9601</td>
#       <td id="T_6687e_row5_col7" class="data row5 col7" >48.44</td>
#       <td id="T_6687e_row5_col8" class="data row5 col8" >3</td>
#       <td id="T_6687e_row5_col9" class="data row5 col9" >-17.10</td>
#       <td id="T_6687e_row5_col10" class="data row5 col10" >41.62</td>
#       <td id="T_6687e_row5_col11" class="data row5 col11" >-9.95</td>
#     </tr>
#     <tr>
#       <th id="T_6687e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6687e_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_6687e_row6_col1" class="data row6 col1" >鴻海</td>
#       <td id="T_6687e_row6_col2" class="data row6 col2" >AI伺服器</td>
#       <td id="T_6687e_row6_col3" class="data row6 col3" >143.00</td>
#       <td id="T_6687e_row6_col4" class="data row6 col4" >159.00</td>
#       <td id="T_6687e_row6_col5" class="data row6 col5" >71155</td>
#       <td id="T_6687e_row6_col6" class="data row6 col6" >120949</td>
#       <td id="T_6687e_row6_col7" class="data row6 col7" >11.80</td>
#       <td id="T_6687e_row6_col8" class="data row6 col8" >0</td>
#       <td id="T_6687e_row6_col9" class="data row6 col9" >8.67</td>
#       <td id="T_6687e_row6_col10" class="data row6 col10" >54.25</td>
#       <td id="T_6687e_row6_col11" class="data row6 col11" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6687e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="

# %%
grouped
# Out:
# <style type="text/css">
# #T_f08de_row0_col1, #T_f08de_row1_col1, #T_f08de_row2_col1, #T_f08de_row3_col1, #T_f08de_row4_col1 {
#   background-color: white;
# }
# #T_f08de_row5_col1, #T_f08de_row6_col1, #T_f08de_row7_col1, #T_f08de_row8_col1, #T_f08de_row9_col1, #T_f08de_row10_col1 {
#   background-color: lightgreen;
# }
# #T_f08de_row11_col1, #T_f08de_row12_col1, #T_f08de_row13_col1, #T_f08de_row14_col1, #T_f08de_row15_col1, #T_f08de_row16_col1, #T_f08de_row17_col1, #T_f08de_row18_col1, #T_f08de_row19_col1, #T_f08de_row20_col1, #T_f08de_row21_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_f08de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f08de_level0_col0" class="col_heading level0 col0" >檔數</th>
#       <th id="T_f08de_level0_col1" class="col_heading level0 col1" >平均漲幅%</th>
#       <th id="T_f08de_level0_col2" class="col_heading level0 col2" >領漲</th>
#       <th id="T_f08de_level0_col3" class="col_heading level0 col3" >領漲漲幅%</th>
#       <th id="T_f08de_level0_col4" class="col_heading level0 col4" >上榜個股</th>
#       <th id="T_f08de_level0_col5" class="col_heading level0 col5" >資金流向(億)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >族群</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f08de_level0_row0" class="row_heading level0 row0" >生技</th>
#       <td id="T_f08de_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_f08de_row0_col1" class="data row0 col1" >1.09</td>
#       <td id="T_f08de_row0_col2" class="data row0 col2" >保瑞</td>
#       <td id="T_f08de_row0_col3" class="data row0 col3" >1.70</td>
#       <td id="T_f08de_row0_col4" class="data row0 col4" >保瑞, 美時</td>
#       <td id="T_f08de_row0_col5" class="data row0 col5" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row1" class="row_heading level0 row1" >海運</th>
#       <td id="T_f08de_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f08de_row1_col1" class="data row1 col1" >0.94</td>
#       <td id="T_f08de_row1_col2" class="data row1 col2" >陽明</td>
#       <td id="T_f08de_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_f08de_row1_col4" class="data row1 col4" >長榮, 陽明</td>
#       <td id="T_f08de_row1_col5" class="data row1 col5" >-2.08</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row2" class="row_heading level0 row2" >儲能</th>
#       <td id="T_f08de_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_f08de_row2_col1" class="data row2 col1" >0.61</td>
#       <td id="T_f08de_row2_col2" class="data row2 col2" >光寶科</td>
#       <td id="T_f08de_row2_col3" class="data row2 col3" >0.73</td>
#       <td id="T_f08de_row2_col4" class="data row2 col4" >台達電, 光寶科</td>
#       <td id="T_f08de_row2_col5" class="data row2 col5" >2.03</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row3" class="row_heading level0 row3" >金融</th>
#       <td id="T_f08de_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_f08de_row3_col1" class="data row3 col1" >0.56</td>
#       <td id="T_f08de_row3_col2" class="data row3 col2" >中信金</td>
#       <td id="T_f08de_row3_col3" class="data row3 col3" >1.13</td>
#       <td id="T_f08de_row3_col4" class="data row3 col4" >中信金, 元大金</td>
#       <td id="T_f08de_row3_col5" class="data row3 col5" >-3.60</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row4" class="row_heading level0 row4" >營建</th>
#       <td id="T_f08de_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_f08de_row4_col1" class="data row4 col1" >0.09</td>
#       <td id="T_f08de_row4_col2" class="data row4 col2" >華固</td>
#       <td id="T_f08de_row4_col3" class="data row4 col3" >7.69</td>
#       <td id="T_f08de_row4_col4" class="data row4 col4" >工信, 華固, 冠德, 長虹, 國產, 國建, 皇昌, 南港</td>
#       <td id="T_f08de_row4_col5" class="data row4 col5" >1.54</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row5" class="row_heading level0 row5" >半導體封裝</th>
#       <td id="T_f08de_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_f08de_row5_col1" class="data row5 col1" >-2.03</td>
#       <td id="T_f08de_row5_col2" class="data row5 col2" >日月光投控</td>
#       <td id="T_f08de_row5_col3" class="data row5 col3" >-1.03</td>
#       <td id="T_f08de_row5_col4" class="data row5 col4" >日月光投控, 京元電子</td>
#       <td id="T_f08de_row5_col5" class="data row5 col5" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row6" class="row_heading level0 row6" >綠能</th>
#       <td id="T_f08de_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_f08de_row6_col1" class="data row6 col1" >-2.09</td>
#       <td id="T_f08de_row6_col2" class="data row6 col2" >上緯投控</td>
#       <td id="T_f08de_row6_col3" class="data row6 col3" >2.41</td>
#       <td id="T_f08de_row6_col4" class="data row6 col4" >世紀鋼, 上緯投控</td>
#       <td id="T_f08de_row6_col5" class="data row6 col5" >2.92</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row7" class="row_heading level0 row7" >半導體矽晶圓</th>
#       <td id="T_f08de_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_f08de_row7_col1" class="data row7 col1" >-2.54</td>
#       <td id="T_f08de_row7_col2" class="data row7 col2" >中美晶</td>
#       <td id="T_f08de_row7_col3" class="data row7 col3" >-1.82</td>
#       <td id="T_f08de_row7_col4" class="data row7 col4" >環球晶, 中美晶</td>
#       <td id="T_f08de_row7_col5" class="data row7 col5" >-3.30</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row8" class="row_heading level0 row8" >傳輸IC</th>
#       <td id="T_f08de_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_f08de_row8_col1" class="data row8 col1" >-3.07</td>
#       <td id="T_f08de_row8_col2" class="data row8 col2" >信驊</td>
#       <td id="T_f08de_row8_col3" class="data row8 col3" >-0.67</td>
#       <td id="T_f08de_row8_col4" class="data row8 col4" >祥碩, 信驊</td>
#       <td id="T_f08de_row8_col5" class="data row8 col5" >-1.19</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row9" class="row_heading level0 row9" >半導體廠務</th>
#       <td id="T_f08de_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_f08de_row9_col1" class="data row9 col1" >-4.08</td>
#       <td id="T_f08de_row9_col2" class="data row9 col2" >漢唐</td>
#       <td id="T_f08de_row9_col3" class="data row9 col3" >-1.25</td>
#       <td id="T_f08de_row9_col4" class="data row9 col4" >漢唐, 牧德</td>
#       <td id="T_f08de_row9_col5" class="data row9 col5" >-1.41</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row10" class="row_heading level0 row10" >AI伺服器</th>
#       <td id="T_f08de_row10_col0" class="data row10 col0" >6</td>
#       <td id="T_f08de_row10_col1" class="data row10 col1" >-4.11</td>
#       <td id="T_f08de_row10_col2" class="data row10 col2" >鴻海</td>
#       <td id="T_f08de_row10_col3" class="data row10 col3" >0.00</td>
#       <td id="T_f08de_row10_col4" class="data row10 col4" >廣達, 緯創, 緯穎, 技嘉, 英業達, 鴻海</td>
#       <td id="T_f08de_row10_col5" class="data row10 col5" >8.67</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row11" class="row_heading level0 row11" >重電</th>
#       <td id="T_f08de_row11_col0" class="data row11 col0" >5</td>
#       <td id="T_f08de_row11_col1" class="data row11 col1" >-5.62</td>
#       <td id="T_f08de_row11_col2" class="data row11 col2" >東元</td>
#       <td id="T_f08de_row11_col3" class="data row11 col3" >-2.34</td>
#       <td id="T_f08de_row11_col4" class="data row11 col4" >華城, 中興電, 士電, 大同, 東元</td>
#       <td id="T_f08de_row11_col5" class="data row11 col5" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_f08de_level0_row12" class="row_heading level0 row12" >手機IC</th>
#       <td id="T_f08de_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_f08de_row12_col1" class="data row12 col1" >-5.71</td>
#       <td id="T_f08de_row12_col2" class="data row12 col2" >聯發科</td>
#       <td id="T_f08de_row12_col3" class="data row12 col3" >-2.72</td>
#       <td id="T_f08de_row12_col4" class="data row12 col4" >聯發科, 瑞昱</td>
#       <td id="T_f08de

# %%
not_grouped
# Out:
# <style type="text/css">
# #T_9471e_row0_col1 {
#   background-color: pink;
# }
# #T_9471e_row1_col1, #T_9471e_row2_col1, #T_9471e_row3_col1, #T_9471e_row4_col1, #T_9471e_row5_col1, #T_9471e_row6_col1, #T_9471e_row7_col1 {
#   background-color: white;
# }
# #T_9471e_row8_col1, #T_9471e_row9_col1, #T_9471e_row10_col1, #T_9471e_row11_col1, #T_9471e_row12_col1 {
#   background-color: lightgreen;
# }
# #T_9471e_row13_col1, #T_9471e_row14_col1, #T_9471e_row15_col1, #T_9471e_row16_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_9471e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9471e_level0_col0" class="col_heading level0 col0" >檔數</th>
#       <th id="T_9471e_level0_col1" class="col_heading level0 col1" >平均漲幅%</th>
#       <th id="T_9471e_level0_col2" class="col_heading level0 col2" >領漲</th>
#       <th id="T_9471e_level0_col3" class="col_heading level0 col3" >領漲漲幅%</th>
#       <th id="T_9471e_level0_col4" class="col_heading level0 col4" >上榜個股</th>
#       <th id="T_9471e_level0_col5" class="col_heading level0 col5" >資金流向(億)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >族群</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9471e_level0_row0" class="row_heading level0 row0" >散裝航</th>
#       <td id="T_9471e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9471e_row0_col1" class="data row0 col1" >4.37</td>
#       <td id="T_9471e_row0_col2" class="data row0 col2" >慧洋-KY</td>
#       <td id="T_9471e_row0_col3" class="data row0 col3" >4.37</td>
#       <td id="T_9471e_row0_col4" class="data row0 col4" >慧洋-KY</td>
#       <td id="T_9471e_row0_col5" class="data row0 col5" >3.97</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row1" class="row_heading level0 row1" >被動元件</th>
#       <td id="T_9471e_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9471e_row1_col1" class="data row1 col1" >1.87</td>
#       <td id="T_9471e_row1_col2" class="data row1 col2" >國巨</td>
#       <td id="T_9471e_row1_col3" class="data row1 col3" >1.87</td>
#       <td id="T_9471e_row1_col4" class="data row1 col4" >國巨</td>
#       <td id="T_9471e_row1_col5" class="data row1 col5" >5.79</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row2" class="row_heading level0 row2" >成衣製鞋</th>
#       <td id="T_9471e_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_9471e_row2_col1" class="data row2 col1" >1.71</td>
#       <td id="T_9471e_row2_col2" class="data row2 col2" >聚陽</td>
#       <td id="T_9471e_row2_col3" class="data row2 col3" >1.71</td>
#       <td id="T_9471e_row2_col4" class="data row2 col4" >聚陽</td>
#       <td id="T_9471e_row2_col5" class="data row2 col5" >2.59</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row3" class="row_heading level0 row3" >航運</th>
#       <td id="T_9471e_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_9471e_row3_col1" class="data row3 col1" >1.61</td>
#       <td id="T_9471e_row3_col2" class="data row3 col2" >長榮航</td>
#       <td id="T_9471e_row3_col3" class="data row3 col3" >1.61</td>
#       <td id="T_9471e_row3_col4" class="data row3 col4" >長榮航</td>
#       <td id="T_9471e_row3_col5" class="data row3 col5" >7.91</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row4" class="row_heading level0 row4" >成熟製程</th>
#       <td id="T_9471e_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_9471e_row4_col1" class="data row4 col1" >-0.41</td>
#       <td id="T_9471e_row4_col2" class="data row4 col2" >聯電</td>
#       <td id="T_9471e_row4_col3" class="data row4 col3" >-0.41</td>
#       <td id="T_9471e_row4_col4" class="data row4 col4" >聯電</td>
#       <td id="T_9471e_row4_col5" class="data row4 col5" >-9.49</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row5" class="row_heading level0 row5" >先進製程</th>
#       <td id="T_9471e_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_9471e_row5_col1" class="data row5 col1" >-1.07</td>
#       <td id="T_9471e_row5_col2" class="data row5 col2" >台積電</td>
#       <td id="T_9471e_row5_col3" class="data row5 col3" >-1.07</td>
#       <td id="T_9471e_row5_col4" class="data row5 col4" >台積電</td>
#       <td id="T_9471e_row5_col5" class="data row5 col5" >-43.67</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row6" class="row_heading level0 row6" >ABF</th>
#       <td id="T_9471e_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_9471e_row6_col1" class="data row6 col1" >-1.47</td>
#       <td id="T_9471e_row6_col2" class="data row6 col2" >欣興</td>
#       <td id="T_9471e_row6_col3" class="data row6 col3" >-1.47</td>
#       <td id="T_9471e_row6_col4" class="data row6 col4" >欣興</td>
#       <td id="T_9471e_row6_col5" class="data row6 col5" >-2.45</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row7" class="row_heading level0 row7" >遊戲</th>
#       <td id="T_9471e_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_9471e_row7_col1" class="data row7 col1" >-2.00</td>
#       <td id="T_9471e_row7_col2" class="data row7 col2" >鈊象</td>
#       <td id="T_9471e_row7_col3" class="data row7 col3" >-2.00</td>
#       <td id="T_9471e_row7_col4" class="data row7 col4" >鈊象</td>
#       <td id="T_9471e_row7_col5" class="data row7 col5" >-6.43</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row8" class="row_heading level0 row8" >DDIC</th>
#       <td id="T_9471e_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_9471e_row8_col1" class="data row8 col1" >-2.38</td>
#       <td id="T_9471e_row8_col2" class="data row8 col2" >聯詠</td>
#       <td id="T_9471e_row8_col3" class="data row8 col3" >-2.38</td>
#       <td id="T_9471e_row8_col4" class="data row8 col4" >聯詠</td>
#       <td id="T_9471e_row8_col5" class="data row8 col5" >-4.49</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row9" class="row_heading level0 row9" >軍工</th>
#       <td id="T_9471e_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_9471e_row9_col1" class="data row9 col1" >-2.60</td>
#       <td id="T_9471e_row9_col2" class="data row9 col2" >漢翔</td>
#       <td id="T_9471e_row9_col3" class="data row9 col3" >-2.60</td>
#       <td id="T_9471e_row9_col4" class="data row9 col4" >漢翔</td>
#       <td id="T_9471e_row9_col5" class="data row9 col5" >-3.97</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row10" class="row_heading level0 row10" >衛星板</th>
#       <td id="T_9471e_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_9471e_row10_col1" class="data row10 col1" >-3.02</td>
#       <td id="T_9471e_row10_col2" class="data row10 col2" >華通</td>
#       <td id="T_9471e_row10_col3" class="data row10 col3" >-3.02</td>
#       <td id="T_9471e_row10_col4" class="data row10 col4" >華通</td>
#       <td id="T_9471e_row10_col5" class="data row10 col5" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row11" class="row_heading level0 row11" >電子紙</th>
#       <td id="T_9471e_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_9471e_row11_col1" class="data row11 col1" >-3.72</td>
#       <td id="T_9471e_row11_col2" class="data row11 col2" >元太</td>
#       <td id="T_9471e_row11_col3" class="data row11 col3" >-3.72</td>
#       <td id="T_9471e_row11_col4" class="data row11 col4" >元太</td>
#       <td id="T_9471e_row11_col5" class="data row11 col5" >-1.61</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row12" class="row_heading level0 row12" >網通</th>
#       <td id="T_9471e_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_9471e_row12_col1" class="data row12 col1" >-4.11</td>
#       <td id="T_9471e_row12_col2" class="data row12 col2" >智邦</td>
#       <td id="T_9471e_row12_col3" class="data row12 col3" >-4.11</td>
#       <td id="T_9471e_row12_col4" class="data row12 col4" >智邦</td>
#       <td id="T_9471e_row12_col5" class="data row12 col5" >-0.62</td>
#     </tr>
#     <tr>
#       <th id="T_9471e_level0_row13" class="row_heading level0 row13" >連接器</th>
#       <td id="T_9471e_row13_col0" class="dat

# %%
search = df[df["族群"] == "其他"]
search = search.sort_values(by="漲幅%", ascending=False).reset_index(drop=True)
columns_to_format = ["成交", "60日高點", "漲幅%", '月營收YoY', '資金流向(億)', "內外盤比"]
search[columns_to_format] = search[columns_to_format].apply(lambda x: x.apply(lambda y: '{:.2f}'.format(y)))
search.style.applymap(set_color_rank, subset=["排名"])
# Out:
# <style type="text/css">
# #T_26992_row0_col0, #T_26992_row1_col0, #T_26992_row2_col0, #T_26992_row3_col0, #T_26992_row4_col0, #T_26992_row5_col0, #T_26992_row6_col0, #T_26992_row7_col0, #T_26992_row8_col0, #T_26992_row9_col0 {
#   background-color: white;
# }
# </style>
# <table id="T_26992">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26992_level0_col0" class="col_heading level0 col0" >排名</th>
#       <th id="T_26992_level0_col1" class="col_heading level0 col1" >商品</th>
#       <th id="T_26992_level0_col2" class="col_heading level0 col2" >族群</th>
#       <th id="T_26992_level0_col3" class="col_heading level0 col3" >成交</th>
#       <th id="T_26992_level0_col4" class="col_heading level0 col4" >60日高點</th>
#       <th id="T_26992_level0_col5" class="col_heading level0 col5" >總量</th>
#       <th id="T_26992_level0_col6" class="col_heading level0 col6" >10日均量</th>
#       <th id="T_26992_level0_col7" class="col_heading level0 col7" >月營收YoY</th>
#       <th id="T_26992_level0_col8" class="col_heading level0 col8" >投信連買天數</th>
#       <th id="T_26992_level0_col9" class="col_heading level0 col9" >資金流向(億)</th>
#       <th id="T_26992_level0_col10" class="col_heading level0 col10" >內外盤比</th>
#       <th id="T_26992_level0_col11" class="col_heading level0 col11" >漲幅%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26992_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26992_row0_col0" class="data row0 col0" >78</td>
#       <td id="T_26992_row0_col1" class="data row0 col1" >群益證</td>
#       <td id="T_26992_row0_col2" class="data row0 col2" >其他</td>
#       <td id="T_26992_row0_col3" class="data row0 col3" >24.70</td>
#       <td id="T_26992_row0_col4" class="data row0 col4" >23.50</td>
#       <td id="T_26992_row0_col5" class="data row0 col5" >55340</td>
#       <td id="T_26992_row0_col6" class="data row0 col6" >22568</td>
#       <td id="T_26992_row0_col7" class="data row0 col7" >45.46</td>
#       <td id="T_26992_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_26992_row0_col9" class="data row0 col9" >4.82</td>
#       <td id="T_26992_row0_col10" class="data row0 col10" >67.84</td>
#       <td id="T_26992_row0_col11" class="data row0 col11" >5.11</td>
#     </tr>
#     <tr>
#       <th id="T_26992_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26992_row1_col0" class="data row1 col0" >98</td>
#       <td id="T_26992_row1_col1" class="data row1 col1" >中石化</td>
#       <td id="T_26992_row1_col2" class="data row1 col2" >其他</td>
#       <td id="T_26992_row1_col3" class="data row1 col3" >10.20</td>
#       <td id="T_26992_row1_col4" class="data row1 col4" >9.93</td>
#       <td id="T_26992_row1_col5" class="data row1 col5" >113418</td>
#       <td id="T_26992_row1_col6" class="data row1 col6" >27079</td>
#       <td id="T_26992_row1_col7" class="data row1 col7" >17.04</td>
#       <td id="T_26992_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_26992_row1_col9" class="data row1 col9" >3.15</td>
#       <td id="T_26992_row1_col10" class="data row1 col10" >63.57</td>
#       <td id="T_26992_row1_col11" class="data row1 col11" >3.98</td>
#     </tr>
#     <tr>
#       <th id="T_26992_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26992_row2_col0" class="data row2 col0" >79</td>
#       <td id="T_26992_row2_col1" class="data row2 col1" >台灣大</td>
#       <td id="T_26992_row2_col2" class="data row2 col2" >其他</td>
#       <td id="T_26992_row2_col3" class="data row2 col3" >104.50</td>
#       <td id="T_26992_row2_col4" class="data row2 col4" >104.50</td>
#       <td id="T_26992_row2_col5" class="data row2 col5" >12438</td>
#       <td id="T_26992_row2_col6" class="data row2 col6" >5561</td>
#       <td id="T_26992_row2_col7" class="data row2 col7" >11.10</td>
#       <td id="T_26992_row2_col8" class="data row2 col8" >2</td>
#       <td id="T_26992_row2_col9" class="data row2 col9" >7.63</td>
#       <td id="T_26992_row2_col10" class="data row2 col10" >79.58</td>
#       <td id="T_26992_row2_col11" class="data row2 col11" >2.45</td>
#     </tr>
#     <tr>
#       <th id="T_26992_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26992_row3_col0" class="data row3 col0" >55</td>
#       <td id="T_26992_row3_col1" class="data row3 col1" >中華電</td>
#       <td id="T_26992_row3_col2" class="data row3 col2" >其他</td>
#       <td id="T_26992_row3_col3" class="data row3 col3" >125.50</td>
#       <td id="T_26992_row3_col4" class="data row3 col4" >127.00</td>
#       <td id="T_26992_row3_col5" class="data row3 col5" >15674</td>
#       <td id="T_26992_row3_col6" class="data row3 col6" >10148</td>
#       <td id="T_26992_row3_col7" class="data row3 col7" >-0.94</td>
#       <td id="T_26992_row3_col8" class="data row3 col8" >3</td>
#       <td id="T_26992_row3_col9" class="data row3 col9" >8.86</td>
#       <td id="T_26992_row3_col10" class="data row3 col10" >72.60</td>
#       <td id="T_26992_row3_col11" class="data row3 col11" >2.03</td>
#     </tr>
#     <tr>
#       <th id="T_26992_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_26992_row4_col0" class="data row4 col0" >88</td>
#       <td id="T_26992_row4_col1" class="data row4 col1" >榮剛</td>
#       <td id="T_26992_row4_col2" class="data row4 col2" >其他</td>
#       <td id="T_26992_row4_col3" class="data row4 col3" >54.20</td>
#       <td id="T_26992_row4_col4" class="data row4 col4" >54.90</td>
#       <td id="T_26992_row4_col5" class="data row4 col5" >22697</td>
#       <td id="T_26992_row4_col6" class="data row4 col6" >19382</td>
#       <td id="T_26992_row4_col7" class="data row4 col7" >2.24</td>
#       <td id="T_26992_row4_col8" class="data row4 col8" >9</td>
#       <td id="T_26992_row4_col9" class="data row4 col9" >-3.12</td>
#       <td id="T_26992_row4_col10" class="data row4 col10" >37.32</td>
#       <td id="T_26992_row4_col11" class="data row4 col11" >-1.28</td>
#     </tr>
#     <tr>
#       <th id="T_26992_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_26992_row5_col0" class="data row5 col0" >36</td>
#       <td id="T_26992_row5_col1" class="data row5 col1" >材料-KY</td>
#       <td id="T_26992_row5_col2" class="data row5 col2" >其他</td>
#       <td id="T_26992_row5_col3" class="data row5 col3" >730.00</td>
#       <td id="T_26992_row5_col4" class="data row5 col4" >1050.00</td>
#       <td id="T_26992_row5_col5" class="data row5 col5" >3857</td>
#       <td id="T_26992_row5_col6" class="data row5 col6" >2571</td>
#       <td id="T_26992_row5_col7" class="data row5 col7" >109.27</td>
#       <td id="T_26992_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_26992_row5_col9" class="data row5 col9" >-7.71</td>
#       <td id="T_26992_row5_col10" class="data row5 col10" >36.48</td>
#       <td id="T_26992_row5_col11" class="data row5 col11" >-4.45</td>
#     </tr>
#     <tr>
#       <th id="T_26992_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_26992_row6_col0" class="data row6 col0" >68</td>
#       <td id="T_26992_row6_col1" class="data row6 col1" >文曄</td>
#       <td id="T_26992_row6_col2" class="data row6 col2" >其他</td>
#       <td id="T_26992_row6_col3" class="data row6 col3" >145.00</td>
#       <td id="T_26992_row6_col4" class="data row6 col4" >175.50</td>
#       <td id="T_26992_row6_col5" class="data row6 col5" >10883</td>
#       <td id="T_26992_row6_col6" class="data row6 col6" >23250</td>
#       <td id="T_26992_row6_col7" class="data row6 col7" >72.03</td>
#       <td id="T_26992_row6_col8" class="data row6 col8" >0</td>
#       <td id="T_26992_row6_col9" class="data row6 col9" >-2.82</td>
#       <td id="T_26992_row6_col10" class="data row6 col10" >41.20</td>
#       <td id="T_26992_row6_col11" class="data row6 col11" >-4.61</td>
#     </tr>
#     <tr>
#       <th id="T_26992_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_26992_row7_col0" class="data row7 col0" >58</td>
#       <td id="T_26992_row7_col1" class="data row7 col1" >矽統</td>
#       <td id="T_26992_row7_col2" class="data row7 col2" >其他</td>
#       <td id="T_26992_row7_col3" class="data row7 col3" >63.20</td>
#       <td id="T_26992_row

# %%
trust = df[df["投信連買天數"] >= 5]
trust = trust.sort_values(by='投信連買天數', ascending=False).reset_index(drop=True)
trust#.style.applymap(set_color_per, subset=['漲幅%'])
# Out:
#     排名    商品       族群     成交    60日高點      總量  10日均量  月營收YoY  投信連買天數  資金流向(億)  \
# 0   28    聯詠     DDIC  574.0   630.00    5547   5223   -6.60      43    -4.49
# 1   51    旺矽  半導體測試介面  368.5   414.00    5376   4971   19.56      17    -1.38
# 2   93    華通      衛星板   73.8    83.50   16119  22219   19.07      12    -0.10
# 3   74    國產       營建   47.0    48.25   29096  14182  -12.11      11     1.77
# 4   69    長虹       營建  124.5   123.00   12035   5519  -60.31       9     0.87
# 5   88    榮剛       其他   54.2    54.90   22697  19382    2.24       9    -3.12
# 6   26  上緯投控       綠能  148.5   146.50   21721   8403   -2.57       8     2.92
# 7   48    華固       營建  161.0   149.50   13968   3277  -99.92       8     1.77
# 8   96    漢唐    半導體廠務  394.5   432.00    2981   3077  -27.76       8    -4.04
# 9    8   中興電       重電  185.0   212.00   51369  84731   12.10       7   -20.37
# 10  70    弘塑    半導體設備  930.0  1110.00    1512   1595   -4.73       7    -2.93
# 11  89  京元電子    半導體封裝   96.0   116.50   12669  13196    7.17       7     0.19
# 12  47    勤誠       機殼  251.0   312.50    8496   5779   54.41       6    -4.16
# 13  19   長榮航       航運   31.6    32.70  132105  71799    8.29       5     7.91
#
#      內外盤比   漲幅%
# 0   43.03 -2.38
# 1   46.59 -7.30
# 2   49.58 -3.02
# 3   56.37 -2.59
# 4   52.87  1.22
# 5   37.32 -1.28
# 6   54.40  2.41
# 7   54.06  7.69
# 8   32.73 -1.25
# 9   39.72 -6.33
# 10  40.05 -9.71
# 11  50.79 -3.03
# 12  40.54 -8.23
# 13  59.39  1.61
